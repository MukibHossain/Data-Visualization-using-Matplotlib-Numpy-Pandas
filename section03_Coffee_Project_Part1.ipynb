# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
coffee = pd.read_csv("total-production.csv").T
coffee.columns = coffee.iloc[0]
coffee = coffee.drop("total_production")
coffee.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# 1991                      746.816   79.653  ...  192.532       54.379
# 1992                      900.111   54.291  ...  196.978       39.084
# 1993                     1019.481   70.046  ...  142.066       37.451
# 1994                     1138.659   24.689  ...  248.313       72.738
#
# total_production Sri Lanka  Thailand     Togo Trinidad & Tobago    Uganda  \
# 1990                 95.87   757.017  161.308            14.581  1955.009
# 1991                81.549  1468.936  432.652            17.792  2088.001
# 1992                53.181  1254.945   85.648            14.328  2185.074
# 1993                 53.79  1275.201  194.939            16.079  3141.706
# 1994                42.448  1399.135  176.296            18.435  2392.753
#
# total_production Venezuela  Viet Nam Yemen
# 1990              1122.477  1310.288   0.0
# 1991               940.704  1437.848   0.0
# 1992              1215.298  2340.447   0.0
# 1993              1332.881  3020.216   0.0
# 1994               988.996  3631.609   0.0
#
# [5 rows x 56 columns]

# %% [markdown]
# # Coffee Production Stats
#
# * Create a bar chart of the top 10 coffee producers by total production in 'total-production.csv', sorted from highest to lowest. Change the xticks to two letter country abbreviations.
#
#
# * Data Prep Code
#
# <mark style="background-color: #000000"> coffee_production = pd.read_csv("coffee/total-production.csv").T </mark>
#
# <mark style="background-color: #000000"> coffee_production.columns = coffee_production.iloc[0] </mark>
#
# <mark style="background-color: #000000"> coffee_production = coffee_production.drop("total_production") </mark>

# %%
coffee.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# 1991                      746.816   79.653  ...  192.532       54.379
# 1992                      900.111   54.291  ...  196.978       39.084
# 1993                     1019.481   70.046  ...  142.066       37.451
# 1994                     1138.659   24.689  ...  248.313       72.738
#
# total_production Sri Lanka  Thailand     Togo Trinidad & Tobago    Uganda  \
# 1990                 95.87   757.017  161.308            14.581  1955.009
# 1991                81.549  1468.936  432.652            17.792  2088.001
# 1992                53.181  1254.945   85.648            14.328  2185.074
# 1993                 53.79  1275.201  194.939            16.079  3141.706
# 1994                42.448  1399.135  176.296            18.435  2392.753
#
# total_production Venezuela  Viet Nam Yemen
# 1990              1122.477  1310.288   0.0
# 1991               940.704  1437.848   0.0
# 1992              1215.298  2340.447   0.0
# 1993              1332.881  3020.216   0.0
# 1994               988.996  3631.609   0.0
#
# [5 rows x 56 columns]

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 1990 to 2018
# Data columns (total 56 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Angola                            29 non-null     object
#  1   Bolivia (Plurinational State of)  29 non-null     object
#  2   Brazil                            29 non-null     object
#  3   Burundi                           29 non-null     object
#  4   Ecuador                           29 non-null     object
#  5   Indonesia                         29 non-null     object
#  6   Madagascar                        29 non-null     object
#  7   Malawi                            29 non-null     object
#  8   Papua New Guinea                  29 non-null     object
#  9   Paraguay                          29 non-null     object
#  10  Peru                              29 non-null     object
#  11  Rwanda                            29 non-null     object
#  12  Timor-Leste                       29 non-null     object
#  13  Zimbabwe                          29 non-null     object
#  14  Congo                             29 non-null     object
#  15  Cuba                              29 non-null     object
#  16  Dominican Republic                29 non-null     object
#  17  Haiti                             29 non-null     object
#  18  Philippines                       29 non-null     object
#  19  Tanzania                          29 non-null     object
#  20  Zambia                            29 non-null     object
#  21  Benin                             29 non-null     object
#  22  Cameroon                          29 non-null     object
#  23  Central African Republic          29 non-null     object
#  24  Colombia                          29 non-null     object
#  25  Costa Rica                        29 non-null     object
#  26  Côte d'Ivoire                     29 non-null     object
#  27  Democratic Republic of Congo      29 non-null     object
#  28  El Salvador                       29 non-null     object
#  29  Equatorial Guinea                 29 non-null     object
#  30  Ethiopia                          29 non-null     object
#  31  Gabon                             29 non-null     object
#  32  Ghana                             29 non-null     object
#  33  Guatemala                         29 non-null     object
#  34  Guinea                            29 non-null     object
#  35  Guyana                            29 non-null     object
#  36  Honduras                          29 non-null     object
#  37  India                             29 non-null     object
#  38  Jamaica                           29 non-null     object
#  39  Kenya                             29 non-null     object
#  40  Lao People's Democratic Republic  29 non-null     object
#  41  Liberia                           29 non-null     object
#  42  Mexico                            29 non-null     object
#  43  Nepal                             29 non-null     object
#  44  Nicaragua                         29 non-null     object
#  45  Nigeria                           29 non-null     object
#  46  Panama                            29 non-null     object
#  47  Sierra Leone                      29 non-null     object
#  48  Sri Lanka                         29 non-null     object
#  49  Thailand                          29 non-null     object
#  50  Togo                              29 non-null     object
#  51  Trinidad & Tobago                 29 non-null     object
#  52  Uganda                            29 non-null     object
#  53  Venezuela                         29 non-null     object
#  54  Viet Nam                          29 non-null     object
#  55  Yemen                             29 non-null     object
# dtypes: object(56)
# memory usage: 12.9+ KB

# %%
top10_producers = coffee.sum().sort_values(ascending = False).iloc[:10]

top10_producers.head()
# Out:
# total_production
# Brazil       1190965.7353
# Viet Nam      439540.9519
# Colombia      345871.4464
# Indonesia     245116.7707
# Ethiopia      141542.8931
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.bar(x = top10_producers.index, height=top10_producers/1000000)

positions = list(range(10))

labels = ["BR", "VN", "CO", "ID", "ET", "IN", "MX", "GT", "HN", "UG"]

ax.set_title("Top coffee by nations")
ax.set_ylabel("Productions (Millions 60 kg bags)", fontsize = 10)
ax.set_xlabel("Country Name", fontsize = 10)

ax.set_xticks(positions)
ax.set_xticklabels(labels)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# # Top 5 over time
#
# * Create a line chart with the top 5 nations over time. Make sure to include a legend! Consider converting the index to datetime64[ns].

# %%
top5 = coffee.loc[:, ["Brazil", "Viet Nam", "Colombia", "Indonesia", "Ethiopia"]]
top5.index = top5.index.astype("datetime64[ns]")

top5.head()
# Out:
# total_production      Brazil  Viet Nam   Colombia Indonesia  Ethiopia
# 1990-01-01        27285.6286  1310.288    14396.0  7441.383  2909.451
# 1991-01-01        27293.4934  1437.848  17980.397  8493.196  2924.664
# 1992-01-01        34603.3542  2340.447  14946.878  5569.478  1825.171
# 1993-01-01        28166.9786  3020.216  11422.422  6743.288  2967.004
# 1994-01-01         28192.047  3631.609    12964.0  5367.878   2762.73

# %%
fig, ax = plt.subplots()

ax.plot(top5.index, coffee["Brazil"] / 1000, label="Brazil")
ax.plot(top5.index, coffee["Viet Nam"] / 1000, label="Viet Nam")
ax.plot(top5.index, coffee["Colombia"] / 1000, label="Colombia")
ax.plot(top5.index, coffee["Indonesia"] / 1000, label="Indonesia")
ax.plot(top5.index, coffee["Ethiopia"] / 1000, label="Ethiopia")

fig.suptitle("Top coffee by nations")
ax.set_title("Brazil is at number 1st spot")
ax.set_ylabel("Productions (Millions 60 kg bags)", fontsize = 10)
ax.set_xlabel("Country Name", fontsize = 10)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.legend()

# %% [markdown]
# # COMPOSITION OVER TIME
#
# Our client is interested in looking at how Brazil's share of global coffee production has changed over time.
#
# Build a plot that global total production as well as Brazil's contribution to global production over time.

# %%
brazil_vs_others = (coffee.assign(rest_of_world = coffee
                                 .drop("Brazil", axis = 1).sum(axis = 1))
                   .loc[:, ["Brazil", "rest_of_world"]]
                   .astype({"Brazil" : "float64"})
                   )
brazil_vs_others.head()
# Out:
# total_production      Brazil rest_of_world
# 1990              27285.6286     65944.431
# 1991              27293.4934     73973.191
# 1992              34603.3542     63922.545
# 1993              28166.9786     63597.643
# 1994              28192.0470     65121.147

# %% [markdown]
# ## PRODUCTION RELATIONSHIPS
#
# We want to explore how Brazil compares to its competitors in terms of production. Build a scatterplot  comparing Brazil Vs. VietNam Production and one comparing Brazil to Venezuela.

# %%
fig, ax = plt.subplots()

ax.scatter(
coffee["Brazil"],
coffee["Venezuela"])

ax.set_title("Venezuela Production Vs Brazil Production")
ax.set_ylabel("Venezuela Production")
ax.set_xlable("Brazil production")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 9
#       7 ax.set_title("Venezuela Production Vs Brazil Production")
#       8 ax.set_ylabel("Venezuela Production")
# ----> 9 ax.set_xlable("Brazil production")
#
# AttributeError: 'Axes' object has no attribute 'set_xlable'

# %%
fig, ax = plt.subplots()

ax.scatter(
coffee["Brazil"],
coffee["Viet Nam"],
)

ax.set_title("Brazil and Viet Nam Production is increating simultenously", color= "purple")
ax.set_ylabel("Viet Nam", color="red")
ax.set_xlabel("Brazil", color= "green")
# Out:
# Text(0.5, 0, 'Brazil')

# %% [markdown]
# # COMPOSITION OF COFFEE PRODUCTION
#
# * Create a Pie chart with the top 5 producers, as well as the sum for the rest of countries.
#
# * Finally, create two donut charts, one representing Brazil's share of global production in 1990, and one for Brazil's share in 2018.

# %%
coffee["Rest of World"] = coffee.drop(["Brazil",
                                      "Viet Nam",
                                      "Colombia",
                                      "Indonesia",
                                      "Ethiopia",], axis=1).sum(axis=1)

coffee_production_top5_2018 = coffee.loc['2018', ["Brazil",
                                                "Viet Nam",
                                                "Colombia",
                                                "Indonesia",
                                                "Ethiopia",
                                                "Rest of World"
                                                ]
                                       ]



coffee_production_top5_2018
# Out:
# total_production
# Brazil           62924.8836
# Viet Nam         31174.0742
# Colombia          13857.962
# Indonesia         9417.5942
# Ethiopia          7776.2234
# Rest of World    45786.0003
# Name: 2018, dtype: object

# %%
fig, ax = plt.subplots()

ax.pie(coffee_production_top5_2018[::-1],
      autopct = "%.0f%%",
      labels= list(coffee_production_top5_2018.index[::-1]),
      startangle = 90)

fig.suptitle("Share of Global Coffee Prodcution 2018")
# Out:
# Text(0.5, 0.98, 'Share of Global Coffee Prodcution 2018')

# %%
brazil_vs_others.head()
# Out:
# total_production      Brazil  rest_of_world
# 1990              27285.6286     105831.740
# 1991              27293.4934     117110.277
# 1992              34603.3542     103163.116
# 1993              28166.9786     103042.356
# 1994              28192.0470     105516.077

# %% [markdown]
# # Coffee Consumption Vs. Prices
#
# Compare coffee prices with coffee consumption in the following countries.
#
# Is there a relationship between coffee consumption and the price these countries pay?
#
# Plot a dual axis bar chart of price vs consumption totals for these countries.

# %%
consumption = pd.read_csv("coffee/imports.csv")


consumption.head()
# Out:
# imports
#    Austria               1551.083333
#    Belgium               4639.533333
#    Belgium/Luxembourg    2329.444444
#    Bulgaria               397.250000
#    Croatia                349.136364
# Name: imports, dtype: float64

# %%
prices = pd.read_csv("coffee/retail-prices.csv")

prices.head()
# Out:
#   retail_prices       1990       1991       1992       1993       1994  \
# 0       Austria  10.816777  10.088300  11.015453  10.971302  10.110375
# 1        Cyprus   6.247241   6.181015   6.335541   5.739514   7.019868
# 2       Denmark   8.410596   8.101545   8.366446   7.682119   9.823400
# 3       Finland   6.578366   6.004415   5.430464   4.282561   6.026490
# 4        France   8.233996   7.571744   5.099338   4.481236   5.298013
#
#         1995       1996       1997       1998  ...       2009       2010  \
# 0  11.434879  11.964680   9.646799   8.763797  ...  15.342163  14.768212
# 1   9.403974   9.116998   8.918322  10.176600  ...  12.207506  11.501104
# 2  12.295806  10.618102  10.949227  10.860927  ...  11.677704  12.008830
# 3   8.763797   7.108168   7.726269   7.549669  ...   7.748344   8.145695
# 4   8.145695   7.284768   6.092715   6.136865  ...   8.366446   7.991170
#
#         2011       2012       2013       2014       2015       2016  \
# 0  18.366446  18.498896  19.028698  19.050773  16.423841  12.450331
# 1  13.377483  14.039735  14.282561  14.304636  11.699779  11.699779
# 2  15.275938  14.834437  14.039735  14.194260  12.913907  10.905077
# 3  11.832230  10.596026   9.470199   9.514349   8.609272   8.101545
# 4   9.116998   8.653422   8.653422   8.322296   6.865342   7.196468
#
#         2017       2018
# 0  13.730684  14.635762
# 1  12.141280  12.781457
# 2  11.103753  11.699779
# 3   9.050773   9.359823
# 4   7.505519   8.123620
#
# [5 rows x 30 columns]

# %%
prices.head()
# Out:
# retail_prices
#    Austria    11.571135
#    Cyprus     10.437695
#    Denmark    10.494025
#    Finland     7.211692
#    France      6.850879
# dtype: float64

# %%
price_cons
# Out:
#         country      Price       Imports
# 5       Germany   9.515110  16357.666667
# 11        Japan  21.472939   6862.275235
# 6         Italy  14.199589   6696.958333
# 4        France   6.850879   6512.458333
# 9         Spain   8.029992   4046.291667
# 7   Netherlands   8.931263   2928.125000
# 10       Sweden   8.054350   1620.625000
# 0       Austria  11.571135   1551.083333
# 3       Finland   7.211692   1157.541667
# 2       Denmark  10.494025    991.791667
# 8      Portugal  10.921063    810.791667
# 12       Norway   9.409302    739.770359
# 1        Cyprus  10.437695     63.791667
